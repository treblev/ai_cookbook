# %% [markdown]
# <a href="https://colab.research.google.com/github/treblev/ai_cookbook/blob/main/nfl_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install nfl_data_py  pandas duckdb
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 86.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 69.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 50.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.10.1 requires pandas<2.2.3dev0,>=2.0, but you have pandas 1.5.3 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 1.5.3 which is incompatible.
# mizani 0.13.1 requires pandas>=2.2.0, but you have pandas 1.5.3 which is incompatible.
# plotnine 0.14.4 requires pandas>=2.2.0, but you have pandas 1.5.3 which is incompatible.
# ...

# %%
import pandas as pd, duckdb as db, nfl_data_py as nfl

# %%
#pbp = nfl.import_pbp_data([2024], downcast=True)

# %%
#nfl.see_weekly_cols()

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
pbp = pd.concat([pd.read_parquet('/content/drive/MyDrive/Data/NFL/pbp/pbp_2016.parquet')
, pd.read_parquet('/content/drive/MyDrive/Data/NFL/pbp/pbp_2017.parquet')
, pd.read_parquet('/content/drive/MyDrive/Data/NFL/pbp/pbp_2018.parquet')
, pd.read_parquet('/content/drive/MyDrive/Data/NFL/pbp/pbp_2019.parquet')
, pd.read_parquet('/content/drive/MyDrive/Data/NFL/pbp/pbp_2020.parquet')
, pd.read_parquet('/content/drive/MyDrive/Data/NFL/pbp/pbp_2021.parquet')
, pd.read_parquet('/content/drive/MyDrive/Data/NFL/pbp/pbp_2022.parquet')
, pd.read_parquet('/content/drive/MyDrive/Data/NFL/pbp/pbp_2020.parquet')
, pd.read_parquet('/content/drive/MyDrive/Data/NFL/pbp/pbp_2023.parquet')
])
teams = pd.read_csv('/content/drive/MyDrive/Data/NFL/NFL_team_data.csv')
teams
# Out:
#                 team_name                home_stadium  \
# 0           Buffalo Bills            Highmark Stadium
# 1          Miami Dolphins           Hard Rock Stadium
# 2    New England Patriots             Gillete Stadium
# 3           New York Jets             MetLife Stadium
# 4          Denver Broncos  Empower Field at Mile High
# 5      Kansas City Chiefs           Arrowhead Stadium
# 6       Las Vegas Raiders           Allegiant Stadium
# 7    Los Angeles Chargers                SoFi Stadium
# 8        Baltimore Ravens            M&T Bank Stadium
# 9      Cincinnati Bengals              Paycor Stadium
# 10       Cleveland Browns    Cleveland Browns Stadium
# 11    Pittsburgh Steelers            Acrisure Stadium
# 12         Houston Texans                 NRG Stadium
# 13     Indianapolis Colts           Lucas Oil Stadium
# 14   Jacksonville Jaguars            EverBank Stadium
# 15       Tennessee Titans              Nissan Stadium
# ...

# %% [markdown]
# roof, surface, temp, wind, game_stadium, start_time, pass_touchdown, rush_touchdown, fourth_down_converted, fourth_down_failed, third_down_converted, third_down_failed, run_location
# run_gap, yards_after_catch, play_type, home or away.

# %% [markdown]
# what is 1. epa? 2. wpa?
